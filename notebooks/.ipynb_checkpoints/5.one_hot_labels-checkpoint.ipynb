# %%
import torch 
import pandas as pd
import numpy as np
import torch.nn.functional as F
from sklearn.preprocessing import OneHotEncoder

# %%
# Import train test and validation sets 
train = np.load('/home/icb/alessandro.palma/data/cellpainting_100/train_data_index.npz', allow_pickle = True)
valid = np.load('/home/icb/alessandro.palma/data/cellpainting_100/val_data_index.npz',  allow_pickle = True)
test = np.load('/home/icb/alessandro.palma/data/cellpainting_100/test_data_index.npz', allow_pickle = True)
ood = np.load('/home/icb/alessandro.palma/data/cellpainting_100/test_data_index.npz', allow_pickle = True)

# %%
train.files
# Out:
# ['filenames', 'mol_names', 'mol_smiles', 'assay_labels']

# %%
len(np.unique((train['mol_names'])))+len(np.unique((ood['mol_names'])))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-bb33fd014506> in <module>
# ----> 1 len(np.unique((train['mol_names'])))+len(np.unique((ood['mol_names'])))
#
# NameError: name 'ood' is not defined

# %%
valid['mol_names'])
# Out:
#   File "<ipython-input-8-9a9f16882795>", line 1
#     valid['mol_names'])
#                       ^
# SyntaxError: unmatched ')'

# %%
len(test['mol_names'])
# Out:
# 57174

# %%
set(train['mol_names']) - set(valid['mol_names'])
# Out:
# {'2-hydroxy-6-phenyl-4-(trifluoromethyl)nicotinonitrile',
#  '4-[4-(trifluoromethyl)phenyl]-4,5,6,7-tetrahydrothieno[3,2-c]pyridine',
#  'BRD-A00697544',
#  'BRD-A01918084',
#  'BRD-A04656563',
#  'BRD-A05072082',
#  'BRD-A05414272',
#  'BRD-A06664848',
#  'BRD-A07764704',
#  'BRD-A07786895',
#  'BRD-A08759443',
#  'BRD-A09886181',
#  'BRD-A12862431',
#  'BRD-A13403390',
#  'BRD-A13920442',
#  'BRD-A15382395',
#  'BRD-A15494458',
#  'BRD-A15911542',
#  'BRD-A16778483',
#  'BRD-A17687311',
#  'BRD-A17815299',
#  'BRD-A22333896',
#  'BRD-A22596080',
#  'BRD-A24067393',
#  'BRD-A24523504',
#  'BRD-A25919039',
#  'BRD-A26168826',
#  'BRD-A26798255',
#  'BRD-A27931246',
#  'BRD-A29506681',
#  'BRD-A30776477',
#  'BRD-A32090136',
#  'BRD-A35158877',
#  'BRD-A35401994',
#  'BRD-A35537528',
#  'BRD-A36897132',
#  'BRD-A37491729',
#  'BRD-A38078247',
#  'BRD-A39837162',
#  'BRD-A39863906',
#  'BRD-A40862551',
#  'BRD-A42388265',
#  'BRD-A44986668',
#  'BRD-A45601407',
#  'BRD-A45667109',
#  'BRD-A46212887',
#  'BRD-A47393232',
#  'BRD-A49235256',
#  'BRD-A51100427',
#  'BRD-A51726689',
#  'BRD-A53107311',
#  'BRD-A53396890',
#  'BRD-A56110059',
#  'BRD-A56119076',
#  'BRD-A57063207',
#  'BRD-A57427373',
#  'BRD-A57640279',
#  'BRD-A61790869',
#  'BRD-A61868010',
#  'BRD-A62548643',
#  'BRD-A62693435',
#  'BRD-A63068258',
#  'BRD-A64728896',
#  'BRD-A65313838',
#  'BRD-A66152327',
#  'BRD-A67481961',
#  'BRD-A67558291',
#  'BRD-A70132191',
#  'BRD-A71239871',
#  'BRD-A73987137',
#  'BRD-A74548703',
#  'BRD-A76457511',
#  'BRD-A76496972',
#  'BRD-A76935636',
#  'BRD-A76985501',
#  'BRD-A78269968',
#  'BRD-A79350583',
#  'BRD-A81030323',
#  'BRD-A83749070',
#  'BRD-A83859334',
#  'BRD-A84517860',
#  'BRD-A84530592',
#  'BRD-A85854481',
#  'BRD-A86636368',
#  'BRD-A86682819',
#  'BRD-A87928000',
#  'BRD-A88022652',
#  'BRD-A88093547',
#  'BRD-A89671349',
#  'BRD-A90006116',
#  'BRD-A93869114',
#  'BRD-A96710964',
#  'BRD-A99377200',
#  'BRD-K00052415',
#  'BRD-K00259552',
#  'BRD-K00266682',
#  'BRD-K00381373',
#  'BRD-K00399969',
#  'BRD-K00571275',
#  'BRD-K00659699',
#  'BRD-K00882705',
#  'BRD-K00888242',
#  'BRD-K01112281',
#  'BRD-K01206861',
#  'BRD-K01294136',
#  'BRD-K01342856',
#  'BRD-K01370799',
#  'BRD-K01990668',
#  'BRD-K02020774',
#  'BRD-K02160136',
#  'BRD-K02458322',
#  'BRD-K02609504',
#  'BRD-K02809100',
#  'BRD-K02939348',
#  'BRD-K02947165',
#  'BRD-K03223543',
#  'BRD-K03301795',
#  'BRD-K03350751',
#  'BRD-K03708099',
#  'BRD-K03775622',
#  'BRD-K03978601',
#  'BRD-K04190958',
#  'BRD-K04198384',
#  'BRD-K04275703',
#  'BRD-K04374239',
#  'BRD-K04408214',
#  'BRD-K04635516',
#  'BRD-K04704273',
#  'BRD-K04968712',
#  'BRD-K05113896',
#  'BRD-K05159099',
#  'BRD-K05222558',
#  'BRD-K05400180',
#  'BRD-K05556515',
#  'BRD-K05748221',
#  'BRD-K05847686',
#  'BRD-K05957858',
#  'BRD-K05975035',
#  'BRD-K06073311',
#  'BRD-K06203014',
#  'BRD-K06485050',
#  'BRD-K06557469',
#  'BRD-K06654104',
#  'BRD-K06696296',
#  'BRD-K06725350',
#  'BRD-K06767101',
#  'BRD-K06816455',
#  'BRD-K06967750',
#  'BRD-K07042471',
#  'BRD-K07612530',
#  'BRD-K07726175',
#  'BRD-K07808993',
#  'BRD-K08252773',
#  'BRD-K08578409',
#  'BRD-K08675565',
#  'BRD-K08831377',
#  'BRD-K08882679',
#  'BRD-K09149805',
#  'BRD-K09167509',
#  'BRD-K09318739',
#  'BRD-K09432998',
#  'BRD-K09558187',
#  'BRD-K10191194',
#  'BRD-K10247312',
#  'BRD-K10509720',
#  'BRD-K10528496',
#  'BRD-K10760636',
#  'BRD-K10899866',
#  'BRD-K10929790',
#  'BRD-K11015166',
#  'BRD-K11191978',
#  'BRD-K11314985',
#  'BRD-K11392760',
#  'BRD-K11578298',
#  'BRD-K12092669',
#  'BRD-K12719224',
#  'BRD-K12724558',
#  'BRD-K12796341',
#  'BRD-K12868284',
#  'BRD-K13235366',
#  'BRD-K13269846',
#  'BRD-K13425292',
#  'BRD-K13556784',
#  'BRD-K13627294',
#  'BRD-K13661881',
#  'BRD-K13883472',
#  'BRD-K14420893',
#  'BRD-K14869008',
#  'BRD-K14954189',
#  'BRD-K15058425',
#  'BRD-K15259298',
#  'BRD-K15449428',
#  'BRD-K15718920',
#  'BRD-K15750886',
#  'BRD-K15778794',
#  'BRD-K15954169',
#  'BRD-K15975837',
#  'BRD-K16064228',
#  'BRD-K16569034',
#  'BRD-K16945760',
#  'BRD-K17364938',
#  'BRD-K17578591',
#  'BRD-K17675685',
#  'BRD-K17680626',
#  'BRD-K17684526',
#  'BRD-K17779381',
#  'BRD-K17785382',
#  'BRD-K17905113',
#  'BRD-K17927475',
#  'BRD-K18026442',
#  'BRD-K18092493',
#  'BRD-K18126494',
#  'BRD-K18170780',
#  'BRD-K18367191',
#  'BRD-K18408518',
#  'BRD-K18426494',
#  'BRD-K18439299',
#  'BRD-K18563051',
#  'BRD-K18764540',
#  'BRD-K19712348',
#  'BRD-K19768759',
#  'BRD-K19829092',
#  'BRD-K19965080',
#  'BRD-K20372127',
#  'BRD-K20679253',
#  'BRD-K20711747',
#  'BRD-K20739802',
#  'BRD-K21094569',
#  'BRD-K21230171',
#  'BRD-K21285405',
#  'BRD-K21453116',
#  'BRD-K21575567',
#  'BRD-K21771449',
#  'BRD-K21799195',
#  'BRD-K21825754',
#  'BRD-K21886573',
#  'BRD-K21930191',
#  'BRD-K22606571',
#  'BRD-K22762517',
#  'BRD-K23046527',
#  'BRD-K23481990',
#  'BRD-K23659898',
#  'BRD-K23710619',
#  'BRD-K23817660',
#  'BRD-K23860736',
#  'BRD-K24301999',
#  'BRD-K24403633',
#  'BRD-K24536086',
#  'BRD-K24588660',
#  'BRD-K24756689',
#  'BRD-K24914740',
#  'BRD-K25016418',
#  'BRD-K25864844',
#  'BRD-K26618362',
#  'BRD-K26669422',
#  'BRD-K26720351',
#  'BRD-K26855844',
#  'BRD-K27022091',
#  'BRD-K27320766',
#  'BRD-K27567433',
#  'BRD-K27608080',
#  'BRD-K27627436',
#  'BRD-K27792853',
#  'BRD-K27996141',
#  'BRD-K28079131',
#  'BRD-K28260634',
#  'BRD-K28295277',
#  'BRD-K28317853',
#  'BRD-K28462004',
#  'BRD-K28714324',
#  'BRD-K28738219',
#  'BRD-K28743880',
#  'BRD-K28746174',
#  'BRD-K28756469',
#  'BRD-K28807341',
#  'BRD-K29165406',
#  'BRD-K29318973',
#  'BRD-K29367859',
#  'BRD-K29702666',
#  'BRD-K29731758',
#  'BRD-K29752393',
#  'BRD-K29828100',
#  'BRD-K29961735',
#  'BRD-K30199050',
#  'BRD-K30309882',
#  'BRD-K30681000',
#  'BRD-K30947691',
#  'BRD-K31380736',
#  'BRD-K31510639',
#  'BRD-K31537290',
#  'BRD-K31584969',
#  'BRD-K32019201',
#  'BRD-K32125060',
#  'BRD-K32664408',
#  'BRD-K32718856',
#  'BRD-K33404682',
#  'BRD-K33408811',
#  'BRD-K33447421',
#  'BRD-K33721685',
#  'BRD-K33766520',
#  'BRD-K34029905',
#  'BRD-K34654169',
#  'BRD-K34676668',
#  'BRD-K34876632',
#  'BRD-K34903299',
#  'BRD-K35044141',
#  'BRD-K35208305',
#  'BRD-K35442564',
#  'BRD-K35615607',
#  'BRD-K35803892',
#  'BRD-K36164005',
#  'BRD-K36189239',
#  'BRD-K36262909',
#  'BRD-K37061750',
#  'BRD-K37228558',
#  'BRD-K37252557',
#  'BRD-K37283718',
#  'BRD-K37929770',
#  'BRD-K37936726',
#  'BRD-K38410475',
#  'BRD-K38446773',
#  'BRD-K38456289',
#  'BRD-K38553273',
#  'BRD-K39154783',
#  'BRD-K39379713',
#  'BRD-K39841630',
#  'BRD-K40256085',
#  'BRD-K40843157',
#  'BRD-K41585006',
#  'BRD-K41734555',
#  'BRD-K41951173',
#  'BRD-K42136676',
#  'BRD-K42493668',
#  'BRD-K42672935',
#  'BRD-K42757079',
#  'BRD-K42893373',
#  'BRD-K43142490',
#  'BRD-K43170076',
#  'BRD-K43440986',
#  'BRD-K43486179',
#  'BRD-K43604417',
#  'BRD-K43722615',
#  'BRD-K43729072',
#  'BRD-K43977780',
#  'BRD-K44371786',
#  'BRD-K44589075',
#  'BRD-K44911800',
#  'BRD-K44976794',
#  'BRD-K45182419',
#  'BRD-K45251697',
#  'BRD-K45862128',
#  'BRD-K46564899',
#  'BRD-K46737922',
#  'BRD-K46804512',
#  'BRD-K46805838',
#  'BRD-K46864030',
#  'BRD-K46961295',
#  'BRD-K47642689',
#  'BRD-K47677644',
#  'BRD-K47707616',
#  'BRD-K48050202',
#  'BRD-K48093976',
#  'BRD-K48319737',
#  'BRD-K48813201',
#  'BRD-K49115566',
#  'BRD-K49297100',
#  'BRD-K49828117',
#  'BRD-K49998974',
#  'BRD-K50094664',
#  'BRD-K50378621',
#  'BRD-K50451780',
#  'BRD-K50537271',
#  'BRD-K50701665',
#  'BRD-K50920395',
#  'BRD-K50932361',
#  'BRD-K51104732',
#  'BRD-K51694032',
#  'BRD-K52124446',
#  'BRD-K52259918',
#  'BRD-K53011428',
#  'BRD-K53045739',
#  'BRD-K53061928',
#  'BRD-K53185063',
#  'BRD-K53376514',
#  'BRD-K53680100',
#  'BRD-K53719842',
#  'BRD-K53842605',
#  'BRD-K54015635',
#  'BRD-K54070802',
#  'BRD-K54279453',
#  'BRD-K54419754',
#  'BRD-K54613724',
#  'BRD-K54664947',
#  'BRD-K54898768',
#  'BRD-K55136906',
#  'BRD-K55274006',
#  'BRD-K56008980',
#  'BRD-K56068834',
#  'BRD-K56224268',
#  'BRD-K56620303',
#  'BRD-K56650430',
#  'BRD-K56657621',
#  'BRD-K56694542',
#  'BRD-K56987179',
#  'BRD-K57064803',
#  'BRD-K57066058',
#  'BRD-K57272712',
#  'BRD-K57634359',
#  'BRD-K57901061',
#  'BRD-K58393684',
#  'BRD-K58429162',
#  'BRD-K58432332',
#  'BRD-K58497506',
#  'BRD-K58703114',
#  'BRD-K58751650',
#  'BRD-K59046064',
#  'BRD-K59061227',
#  'BRD-K59420052',
#  'BRD-K59501784',
#  'BRD-K59749740',
#  'BRD-K59905302',
#  'BRD-K60022045',
#  'BRD-K60217006',
#  'BRD-K60343011',
#  'BRD-K60435968',
#  'BRD-K60837711',
#  'BRD-K61055471',
#  'BRD-K61223648',
#  'BRD-K61367931',
#  'BRD-K61407677',
#  'BRD-K61415887',
#  'BRD-K61432385',
#  'BRD-K61454150',
#  'BRD-K61455847',
#  'BRD-K61596148',
#  'BRD-K61627029',
#  'BRD-K61651281',
#  'BRD-K62613235',
#  'BRD-K62615721',
#  'BRD-K62810034',
#  'BRD-K62911960',
#  'BRD-K62987569',
#  'BRD-K63093217',
#  'BRD-K63431240',
#  'BRD-K63478344',
#  'BRD-K63707385',
#  'BRD-K63988672',
#  'BRD-K64069148',
#  'BRD-K64184910',
#  'BRD-K64326672',
#  'BRD-K64336474',
#  'BRD-K64345025',
#  'BRD-K64592938',
#  'BRD-K64642724',
#  'BRD-K64645183',
#  'BRD-K64730883',
#  'BRD-K64738596',
#  'BRD-K65277915',
#  'BRD-K65378652',
#  'BRD-K65400733',
#  'BRD-K65440031',
#  'BRD-K65727917',
#  'BRD-K65731773',
#  'BRD-K65788620',
#  'BRD-K66008044',
#  'BRD-K66372234',
#  'BRD-K66803903',
#  'BRD-K67301886',
#  'BRD-K67394135',
#  'BRD-K67591367',
#  'BRD-K67831601',
#  'BRD-K67856310',
#  'BRD-K67862512',
#  'BRD-K68076329',
#  'BRD-K68270321',
#  'BRD-K68390130',
#  'BRD-K68443944',
#  'BRD-K68627737',
#  'BRD-K68661868',
#  'BRD-K68758518',
#  'BRD-K68852533',
#  'BRD-K69123433',
#  'BRD-K69411451',
#  'BRD-K69609532',
#  'BRD-K69740426',
#  'BRD-K69771711',
#  'BRD-K69808609',
#  'BRD-K70032220',
#  'BRD-K70054078',
#  'BRD-K70551979',
#  'BRD-K70627229',
#  'BRD-K70838267',
#  'BRD-K70839485',
#  'BRD-K71243741',
#  'BRD-K71520299',
#  'BRD-K71575796',
#  'BRD-K71632520',
#  'BRD-K71912544',
#  'BRD-K71919342',
#  'BRD-K72107498',
#  'BRD-K72363785',
#  'BRD-K72541630',
#  'BRD-K72628262',
#  'BRD-K72778748',
#  'BRD-K72797880',
#  'BRD-K72851839',
#  'BRD-K73062809',
#  'BRD-K73261251',
#  'BRD-K73500089',
#  'BRD-K73553469',
#  'BRD-K73873941',
#  'BRD-K73875306',
#  'BRD-K73953291',
#  'BRD-K74121099',
#  'BRD-K74196031',
#  'BRD-K74430653',
#  'BRD-K74656131',
#  'BRD-K75007194',
#  'BRD-K75074041',
#  'BRD-K75094142',
#  'BRD-K75910910',
#  'BRD-K76425737',
#  'BRD-K76459967',
#  'BRD-K76524005',
#  'BRD-K76578350',
#  'BRD-K76662562',
#  'BRD-K76734823',
#  'BRD-K77161059',
#  'BRD-K77189681',
#  'BRD-K77338217',
#  'BRD-K77548756',
#  'BRD-K78051552',
#  'BRD-K78122650',
#  'BRD-K78222443',
#  'BRD-K78388870',
#  'BRD-K78412459',
#  'BRD-K78438852',
#  'BRD-K78484850',
#  'BRD-K78599344',
#  'BRD-K78791054',
#  'BRD-K78797196',
#  'BRD-K78809123',
#  'BRD-K79303561',
#  'BRD-K79431521',
#  'BRD-K79442413',
#  'BRD-K79931204',
#  'BRD-K79971029',
#  'BRD-K80217331',
#  'BRD-K80384269',
#  'BRD-K80531070',
#  'BRD-K80622725',
#  'BRD-K80726734',
#  'BRD-K80794552',
#  'BRD-K80983134',
#  'BRD-K81034231',
#  'BRD-K81139344',
#  'BRD-K81339550',
#  'BRD-K81789730',
#  'BRD-K82011025',
#  'BRD-K82203327',
#  'BRD-K82339068',
#  'BRD-K82535917',
#  'BRD-K83739153',
#  'BRD-K83821605',
#  'BRD-K83842983',
#  'BRD-K83845975',
#  'BRD-K83882946',
#  'BRD-K84013239',
#  'BRD-K84107377',
#  'BRD-K84383600',
#  'BRD-K84427671',
#  'BRD-K84479162',
#  'BRD-K84541452',
#  'BRD-K84605058',
#  'BRD-K84767166',
#  'BRD-K84989887',
#  'BRD-K85112460',
#  'BRD-K85218343',
#  'BRD-K85393703',
#  'BRD-K85492583',
#  'BRD-K85532298',
#  'BRD-K85999141',
#  'BRD-K86110370',
#  'BRD-K86307212',
#  'BRD-K86764418',
#  'BRD-K86876475',
#  'BRD-K86942182',
#  'BRD-K86968750',
#  'BRD-K87049226',
#  'BRD-K87213231',
#  'BRD-K87256167',
#  'BRD-K87338678',
#  'BRD-K87569241',
#  'BRD-K87705545',
#  'BRD-K87742379',
#  'BRD-K87994814',
#  'BRD-K88030905',
#  'BRD-K88033714',
#  'BRD-K88161155',
#  'BRD-K88223257',
#  'BRD-K88578764',
#  'BRD-K88662980',
#  'BRD-K88806900',
#  'BRD-K88861635',
#  'BRD-K88922243',
#  'BRD-K89177913',
#  'BRD-K89416748',
#  'BRD-K89785473',
#  'BRD-K89873893',
#  'BRD-K89900849',
#  'BRD-K90002972',
#  'BRD-K90062066',
#  'BRD-K90294313',
#  'BRD-K90334416',
#  'BRD-K90449413',
#  'BRD-K90545149',
#  'BRD-K90704198',
#  'BRD-K90793377',
#  'BRD-K90884091',
#  'BRD-K90918886',
#  'BRD-K90965240',
#  'BRD-K91150572',
#  'BRD-K91320102',
#  'BRD-K91558541',
#  'BRD-K91804968',
#  'BRD-K92014291',
#  'BRD-K92105860',
#  'BRD-K92155238',
#  'BRD-K92284884',
#  'BRD-K92362926',
#  'BRD-K92551462',
#  'BRD-K92576167',
#  'BRD-K93036943',
#  'BRD-K93077412',
#  'BRD-K93124351',
#  'BRD-K93194316',
#  'BRD-K93248080',
#  'BRD-K93397704',
#  'BRD-K93520959',
#  'BRD-K93701319',
#  'BRD-K93742092',
#  'BRD-K93766911',
#  'BRD-K93953657',
#  'BRD-K94087238',
#  'BRD-K94177950',
#  'BRD-K94191869',
#  'BRD-K94361931',
#  'BRD-K95153924',
#  'BRD-K95356204',
#  'BRD-K95760264',
#  'BRD-K96254830',
#  'BRD-K96390140',
#  'BRD-K96448807',
#  'BRD-K96510191',
#  'BRD-K96605449',
#  'BRD-K96609500',
#  'BRD-K96773131',
#  'BRD-K96841301',
#  'BRD-K97357300',
#  'BRD-K97414323',
#  'BRD-K97754781',
#  'BRD-K97846172',
#  'BRD-K97902511',
#  'BRD-K98065258',
#  'BRD-K98220872',
#  'BRD-K98272474',
#  'BRD-K98695520',
#  'BRD-K98704231',
#  'BRD-K98740057',
#  'BRD-K99019859',
#  'BRD-K99034148',
#  'BRD-K99043334',
#  'BRD-K99347713',
#  'BRD-K99377470',
#  'ML025',
#  'ML038',
#  'ML097',
#  'ML144',
#  'ML150',
#  'ML158',
#  'ML160',
#  'N2-(3,4-dimethylphenyl)-5-(2-aminophenyl)-1,3,4-oxadiazol-2-amine'}

# %%
len(set(test['mol_names'])-set(train['mol_names']) )
# Out:
# 0

# %%
# Collect seen and unseen 
seen, unseen = np.load('/home/icb/alessandro.palma/imCPA/data/metadata_processed/seen_unseen_compounds.npz', allow_pickle=True).values()

# %%
len(seen)
# Out:
# 10261

# %%
len(unseen)
# Out:
# 299

# %%
seen_sorted = sorted(seen)
drug_to_id = {d:i for d,i in zip(seen_sorted, range(len((seen_sorted))))}

# %%
encoder_drug = OneHotEncoder(
    sparse=False, categories=[seen_sorted])

# %%
encoder_drug.fit(np.array(seen_sorted).reshape((-1,1)))
# Out:
# OneHotEncoder(categories=[['( R)-(+)-WIN 55,212-2 mesylate[(R)-(+)-[2,3-Dihydro-5-methyl-3[(morpholinyl)methyl]pyrrolo[1,2,3-de]-1,4-benzoxazinyl]-(]',
#                            '(+)-UH 232', '(+)-isocorydine', '(+/-)-PPHT',
#                            '(+/-)-kavain', '(?)-AC 7954 hydrochloride',
#                            '(?)-Epinephrine hydrochloride[(?)-Adrenalin hydrochloride]',
#                            '(R)-(+)-8-Hydroxy-DPAT hydrobromide',
#                            '(R)-(+)-atenolol', '(R...
#                            '1-(2,3-dihydro-1H-indol-1-yl)-2-(phenylsulfanyl)-1-ethanone',
#                            '1-(2-METHOXYPHENYL)-4-(4-SUCCINIMIDOBUTYL)PIPERAZINE',
#                            '1-(2-methoxyphenyl)piperazine',
#                            '1-(3-chlorophenyl)piperazine',
#                            '1-(3-trifluoromethylphenyl)piperazine',
#                            "1-(4'-AMINOPHENYL)-3,5-DIHYDRO-7,8-DIMETHOXY-4H-2,3-BENZODIAZEPIN-4-ONE",
#                            '1-(4,6-Dimethylpyrimidin-2-yl)piperidine-4-carboxylic acid', ...]],
#               sparse=False)

# %%
encoder_drug.transform(np.array(ood['mol_names'].reshape((-1,1))))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-161-338a5f80187d> in <module>
# ----> 1 encoder_drug.transform(np.array(ood['mol_names'].reshape((-1,1))))
#
# NameError: name 'ood' is not defined

# %% [markdown]
# * Change splits: one training, one validation, one test and one OOD
# * Change the data loading object
# * Implement classifiers: from latent to drug (on non-OOD), from latent to morphology, assay from image features

# %%
df = pd.read_csv('/home/icb/alessandro.palma/eval_heldout_set.csv')

# %%
np.unique(df.CPD_NAME, return_counts=True)

# %%
test['mol_names'][test['mol_names']=='PAPP']
# Out:
# array(['PAPP', 'PAPP', 'PAPP', 'PAPP', 'PAPP', 'PAPP', 'PAPP', 'PAPP',
#        'PAPP', 'PAPP', 'PAPP', 'PAPP', 'PAPP', 'PAPP', 'PAPP', 'PAPP',
#        'PAPP', 'PAPP', 'PAPP', 'PAPP', 'PAPP', 'PAPP', 'PAPP', 'PAPP',
#        'PAPP', 'PAPP', 'PAPP', 'PAPP', 'PAPP', 'PAPP', 'PAPP', 'PAPP',
#        'PAPP', 'PAPP', 'PAPP', 'PAPP', 'PAPP', 'PAPP', 'PAPP', 'PAPP',
#        'PAPP', 'PAPP', 'PAPP', 'PAPP', 'PAPP', 'PAPP', 'PAPP', 'PAPP'],
#       dtype=object)
