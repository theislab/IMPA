# %%
import sys 
sys.path.insert(0, "home/icb/alessandro.palma/")  # this depends on the notebook depth and must be adapted per notebook
import numpy as np
from joblib import Parallel, delayed
from tqdm.notebook import tqdm
import pandas as pd 
import os
from joblib import Parallel, delayed
from tqdm.notebook import tqdm

# %%
# Name of the dataset 
dataset_name = 'cellpainting'
data_dir = '/home/icb/alessandro.palma/data/metadata_processed/integrated/200k/splits/'

# Get the training and ood splits (containing the whole set of drugs in the dataset)
training_set = pd.read_csv(os.path.join(data_dir, 'datasplit-train.csv'))
ood_set = pd.read_csv(os.path.join(data_dir, 'datasplit-ood.csv'))

# %%
training_set_unique = training_set.drop_duplicates(subset=['SMILES'])
ood_set_unique = ood_set.drop_duplicates(subset=['SMILES'])

# %%
# Paste the two datasets 
dataset = pd.concat([training_set_unique, ood_set_unique],ignore_index = True)
smiles = dataset.SMILES.to_numpy()

# %%
from descriptastorus.descriptors.DescriptorGenerator import MakeGenerator
# Out:
# WARNING:root:No normalization for BCUT2D_MWHI
# WARNING:root:No normalization for BCUT2D_MWLOW
# WARNING:root:No normalization for BCUT2D_CHGHI
# WARNING:root:No normalization for BCUT2D_CHGLO
# WARNING:root:No normalization for BCUT2D_LOGPHI
# WARNING:root:No normalization for BCUT2D_LOGPLOW
# WARNING:root:No normalization for BCUT2D_MRHI
# WARNING:root:No normalization for BCUT2D_MRLOW

# %%
# Create the generator for rdkit features 
generator = MakeGenerator(("RDKit2D",))

# %%
for name, numpy_type in generator.GetColumns():
    print(f"{name}({numpy_type.__name__})")
# Out:
# RDKit2D_calculated(bool)
# BalabanJ(float64)
# BertzCT(float64)
# Chi0(float64)
# Chi0n(float64)
# Chi0v(float64)
# Chi1(float64)
# Chi1n(float64)
# Chi1v(float64)
# Chi2n(float64)
# Chi2v(float64)
# Chi3n(float64)
# Chi3v(float64)
# Chi4n(float64)
# Chi4v(float64)
# EState_VSA1(float64)
# EState_VSA10(float64)
# EState_VSA11(float64)
# EState_VSA2(float64)
# EState_VSA3(float64)
# EState_VSA4(float64)
# EState_VSA5(float64)
# EState_VSA6(float64)
# EState_VSA7(float64)
# EState_VSA8(float64)
# EState_VSA9(float64)
# ExactMolWt(float64)
# FpDensityMorgan1(float64)
# FpDensityMorgan2(float64)
# FpDensityMorgan3(float64)
# FractionCSP3(float64)
# HallKierAlpha(float64)
# HeavyAtomCount(float64)
# HeavyAtomMolWt(float64)
# Ipc(float64)
# Kappa1(float64)
# Kappa2(float64)
# Kappa3(float64)
# LabuteASA(float64)
# MaxAbsEStateIndex(float64)
# MaxAbsPartialCharge(float64)
# MaxEStateIndex(float64)
# MaxPartialCharge(float64)
# MinAbsEStateIndex(float64)
# MinAbsPartialCharge(float64)
# MinEStateIndex(float64)
# MinPartialCharge(float64)
# MolLogP(float64)
# MolMR(float64)
# MolWt(float64)
# NHOHCount(float64)
# NOCount(float64)
# NumAliphaticCarbocycles(float64)
# NumAliphaticHeterocycles(float64)
# NumAliphaticRings(float64)
# NumAromaticCarbocycles(float64)
# NumAromaticHeterocycles(float64)
# NumAromaticRings(float64)
# NumHAcceptors(float64)
# NumHDonors(float64)
# NumHeteroatoms(float64)
# NumRadicalElectrons(float64)
# NumRotatableBonds(float64)
# NumSaturatedCarbocycles(float64)
# NumSaturatedHeterocycles(float64)
# NumSaturatedRings(float64)
# NumValenceElectrons(float64)
# PEOE_VSA1(float64)
# PEOE_VSA10(float64)
# PEOE_VSA11(float64)
# PEOE_VSA12(float64)
# PEOE_VSA13(float64)
# PEOE_VSA14(float64)
# PEOE_VSA2(float64)
# PEOE_VSA3(float64)
# PEOE_VSA4(float64)
# PEOE_VSA5(float64)
# PEOE_VSA6(float64)
# PEOE_VSA7(float64)
# PEOE_VSA8(float64)
# PEOE_VSA9(float64)
# RingCount(float64)
# SMR_VSA1(float64)
# SMR_VSA10(float64)
# SMR_VSA2(float64)
# SMR_VSA3(float64)
# SMR_VSA4(float64)
# SMR_VSA5(float64)
# SMR_VSA6(float64)
# SMR_VSA7(float64)
# SMR_VSA8(float64)
# SMR_VSA9(float64)
# SlogP_VSA1(float64)
# SlogP_VSA10(float64)
# SlogP_VSA11(float64)
# SlogP_VSA12(float64)
# SlogP_VSA2(float64)
# SlogP_VSA3(float64)
# SlogP_VSA4(float64)
# SlogP_VSA5(float64)
# SlogP_VSA6(float64)
# SlogP_VSA7(float64)
# SlogP_VSA8(float64)
# SlogP_VSA9(float64)
# TPSA(float64)
# VSA_EState1(float64)
# VSA_EState10(float64)
# VSA_EState2(float64)
# VSA_EState3(float64)
# VSA_EState4(float64)
# VSA_EState5(float64)
# VSA_EState6(float64)
# VSA_EState7(float64)
# VSA_EState8(float64)
# VSA_EState9(float64)
# fr_Al_COO(float64)
# fr_Al_OH(float64)
# fr_Al_OH_noTert(float64)
# fr_ArN(float64)
# fr_Ar_COO(float64)
# fr_Ar_N(float64)
# fr_Ar_NH(float64)
# fr_Ar_OH(float64)
# fr_COO(float64)
# fr_COO2(float64)
# fr_C_O(float64)
# fr_C_O_noCOO(float64)
# fr_C_S(float64)
# fr_HOCCN(float64)
# fr_Imine(float64)
# fr_NH0(float64)
# fr_NH1(float64)
# fr_NH2(float64)
# fr_N_O(float64)
# fr_Ndealkylation1(float64)
# fr_Ndealkylation2(float64)
# fr_Nhpyrrole(float64)
# fr_SH(float64)
# fr_aldehyde(float64)
# fr_alkyl_carbamate(float64)
# fr_alkyl_halide(float64)
# fr_allylic_oxid(float64)
# fr_amide(float64)
# fr_amidine(float64)
# fr_aniline(float64)
# fr_aryl_methyl(float64)
# fr_azide(float64)
# fr_azo(float64)
# fr_barbitur(float64)
# fr_benzene(float64)
# fr_benzodiazepine(float64)
# fr_bicyclic(float64)
# fr_diazo(float64)
# fr_dihydropyridine(float64)
# fr_epoxide(float64)
# fr_ester(float64)
# fr_ether(float64)
# fr_furan(float64)
# fr_guanido(float64)
# fr_halogen(float64)
# fr_hdrzine(float64)
# fr_hdrzone(float64)
# fr_imidazole(float64)
# fr_imide(float64)
# fr_isocyan(float64)
# fr_isothiocyan(float64)
# fr_ketone(float64)
# fr_ketone_Topliss(float64)
# fr_lactam(float64)
# fr_lactone(float64)
# fr_methoxy(float64)
# fr_morpholine(float64)
# fr_nitrile(float64)
# fr_nitro(float64)
# fr_nitro_arom(float64)
# fr_nitro_arom_nonortho(float64)
# fr_nitroso(float64)
# fr_oxazole(float64)
# fr_oxime(float64)
# fr_para_hydroxylation(float64)
# fr_phenol(float64)
# fr_phenol_noOrthoHbond(float64)
# fr_phos_acid(float64)
# fr_phos_ester(float64)
# fr_piperdine(float64)
# fr_piperzine(float64)
# fr_priamide(float64)
# fr_prisulfonamd(float64)
# fr_pyridine(float64)
# fr_quatN(float64)
# fr_sulfide(float64)
# fr_sulfonamd(float64)
# fr_sulfone(float64)
# fr_term_acetylene(float64)
# fr_tetrazole(float64)
# fr_thiazole(float64)
# fr_thiocyan(float64)
# fr_thiophene(float64)
# fr_unbrch_alkane(float64)
# fr_urea(float64)
# qed(float64)

# %%
n_jobs = 16
data = Parallel(n_jobs=n_jobs)(delayed(generator.process)(smile) for smile in smiles )

# %%
embedding = np.array(data)

# %% [markdown]
# Check for the presence of nans or infinity

# %%
# Check for nans
drug_idx, feature_idx = np.where(np.isnan(embedding))
print(f'drug_idx:\n {drug_idx}')
print(f'feature_idx:\n {feature_idx}')
# Out:
# drug_idx:
#  [956 956 956 956]
# feature_idx:
#  [40 42 44 46]

# %%
drug_idx_infs, feature_idx_infs = np.where(np.isinf(embedding))
print(f'drug_idx:\n {drug_idx_infs}')
print(f'feature_idx:\n {feature_idx_infs}')
# Out:
# drug_idx:
#  []
# feature_idx:
#  []

# %%
drug_idx = np.concatenate((drug_idx, drug_idx_infs))
feature_idx = np.concatenate((feature_idx, feature_idx_infs))

# %%
# Features where the data has nan values
np.array(generator.GetColumns())[np.unique(feature_idx)]
# Out:
# array([['MaxAbsPartialCharge', <class 'numpy.float64'>],
#        ['MaxPartialCharge', <class 'numpy.float64'>],
#        ['MinAbsPartialCharge', <class 'numpy.float64'>],
#        ['MinPartialCharge', <class 'numpy.float64'>]], dtype=object)

# %%
# Check if indeed the content is NaN 
embedding[drug_idx, feature_idx]
# Out:
# array([0., 0., 0., 0.])

# %%
# Turn values to 0
embedding[drug_idx, feature_idx] = 0

# %% [markdown]
# ## Save and normalize

# %%
# Convert to df
df = pd.DataFrame(data=embedding, index=smiles, columns=[f'latent_{i}' for i in range(embedding.shape[1])]) 

# Drop first feature from generator (RDKit2D_calculated)
df.drop(columns=['latent_0'], inplace=True)

# Drop columns with 0 standard deviation
threshold = 0.01
columns=[f'latent_{idx+1}' for idx in np.where(df.std() <= threshold)[0]]
print(f'Deleting columns with std<={threshold}: {columns}')
df.drop(columns=[f'latent_{idx+1}' for idx in np.where(df.std() <= 0.01)[0]], inplace=True)
# Out:
# Deleting columns with std<=0.01: ['latent_90', 'latent_103', 'latent_146', 'latent_152', 'latent_164', 'latent_165', 'latent_176', 'latent_187']

# %%
# Control if the right columns were removed
np.where(df.std() <= threshold)
# Out:
# (array([], dtype=int64),)

# %%
# Normalize features 
normalized_df=(df-df.mean())/df.std()

# %%
normalized_df
# Out:
#                                                     latent_1  latent_2  \
# O=C(COC(=O)c1nn(-c2ccccc2)c(=O)c2ccccc12)NC1CCS... -0.750603  1.491529
# Cc1cc(cc(C)c1CC1=NCCN1)C(C)(C)C                    -0.705891 -1.233662
# CCCOc1ccccc1-c1nc2[nH]nnc2c(=O)[nH]1               -1.045148 -0.787284
#
#                                                     latent_7  latent_8  \
# O=C(COC(=O)c1nn(-c2ccccc2)c(=O)c2ccccc12)NC1CCS...  0.554524  0.980037
# C1COCCOCCOc2ccccc2OCCOCCOCCOc2ccccc2OCCOCCO1        2.024009  1.648676
# [O-][N+](=O)c1ccc(cc1)-c1nc(c([nH]1)-c1ccncc1)-... -0.055359 -0.320068
# FC(F)(F)c1cccc(Nc2ncccc2C(=O)OC2OC(=O)c3ccccc23)c1  0.196621 -0.081494
# C[C@@H](O)C#Cc1ccc2c(O[C@@H](CN(C)Cc3ccc(cc3)-c...  2.212934  2.398928
# ...                                                      ...       ...
# CCOC(=O)Oc1c(OC)cc(cc1OC)C(=O)O[C@@H]1C[C@@H]2C...  3.282325  2.840049
# COc1ccc2C[C@@H]3N(C)CCc4cc(OC)c(OC)c(Oc5cc6[C@H...  3.205266  2.767090
# CC(C)(C)c1cc(C=C(C#N)C#N)cc(c1O)C(C)(C)C           -0.568812 -0.806205
# Cc1cc(cc(C)c1CC1=NCCN1)C(C)(C)C                    -0.630698 -0.864798
# CCCOc1ccccc1-c1nc2[nH]nnc2c(=O)[nH]1               -0.810640 -1.035168
#
#                                                     latent_9  latent_10  ...  \
# O=C(COC(=O)c1nn(-c2ccccc2)c(=O)c2ccccc12)NC1CCS...  0.527846   1.114139  ...
# C1COCCOCCOc2ccccc2OCCOCCOCCOc2ccccc2OCCOCCO1        0.911624   0.465929  ...
# [O-][N+](=O)c1ccc(cc1)-c1nc(c([nH]1)-c1ccncc1)-... -0.136217  -0.470610  ...
# FC(F)(F)c1cccc(Nc2ncccc2C(=O)OC2OC(=O)c3ccccc23)c1  0.101213  -0.258400  ...
# C[C@@H](O)C#Cc1ccc2c(O[C@@H](CN(C)Cc3ccc(cc3)-c...  2.227727   2.469015  ...
# ...                                                      ...        ...  ...
# CCOC(=O)Oc1c(OC)cc(cc1OC)C(=O)O[C@@H]1C[C@@H]2C...  3.056922   2.383355  ...
# COc1ccc2C[C@@H]3N(C)CCc4cc(OC)c(OC)c(Oc5cc6[C@H...  3.145208   2.462263  ...
# CC(C)(C)c1cc(C=C(C#N)C#N)cc(c1O)C(C)(C)C            0.555687   0.147800  ...
# Cc1cc(cc(C)c1CC1=NCCN1)C(C)(C)C                     0.070180  -0.286136  ...
# CCCOc1ccccc1-c1nc2[nH]nnc2c(=O)[nH]1               -0.926219  -1.176698  ...
#
#                                                     latent_191  latent_192  \
# O=C(COC(=O)c1nn(-c2ccccc2)c(=O)c2ccccc12)NC1CCS...   -0.364122    8.337882
# C1COCCOCCOc2ccccc2OCCOCCOCCOc2ccccc2OCCOCCO1         -0.364122   -0.118302
# [O-][N+](=O)c1ccc(cc1)-c1nc(c([nH]1)-c1ccncc1)-...   -0.364122   -0.118302
# FC(F)(F)c1cccc(Nc2ncccc2C(=O)OC2OC(=O)c3ccccc23)c1   -0.364122   -0.118302
# O=C(COC(=O)c1nn(-c2ccccc2)c(=O)c2ccccc12)NC1CCS...   -0.302587   -0.179321
# C1COCCOCCOc2ccccc2OCCOCCOCCOc2ccccc2OCCOCCO1         -0.302587   -0.179321
# [O-][N+](=O)c1ccc(cc1)-c1nc(c([nH]1)-c1ccncc1)-...   -0.302587   -0.179321
# FC(F)(F)c1cccc(Nc2ncccc2C(=O)OC2OC(=O)c3ccccc23)c1   -0.302587   -0.179321
# C[C@@H](O)C#Cc1ccc2c(O[C@@H](CN(C)Cc3ccc(cc3)-c...   -0.302587   -0.179321
# ...                                                        ...         ...
# CCOC(=O)Oc1c(OC)cc(cc1OC)C(=O)O[C@@H]1C[C@@H]2C...   -0.302587   -0.179321
# COc1ccc2C[C@@H]3N(C)CCc4cc(OC)c(OC)c(Oc5cc6[C@H...   -0.302587   -0.179321
# CC(C)(C)c1cc(C=C(C#N)C#N)cc(c1O)C(C)(C)C             -0.302587   -0.179321
# Cc1cc(cc(C)c1CC1=NCCN1)C(C)(C)C                      -0.302587   -0.179321
# CCCOc1ccccc1-c1nc2[nH]nnc2c(=O)[nH]1                 -0.302587   -0.179321
#
#                                                     latent_199  latent_200
# O=C(COC(=O)c1nn(-c2ccccc2)c(=O)c2ccccc12)NC1CCS...   -0.245922   -0.236757
# C1COCCOCCOc2ccccc2OCCOCCOCCOc2ccccc2OCCOCCO1         -0.245922   -0.704320
# [O-][N+](=O)c1ccc(cc1)-c1nc(c([nH]1)-c1ccncc1)-...   -0.245922   -1.186060
# FC(F)(F)c1cccc(Nc2ncccc2C(=O)OC2OC(=O)c3ccccc23)c1   -0.245922   -0.053327
# C[C@@H](O)C#Cc1ccc2c(O[C@@H](CN(C)Cc3ccc(cc3)-c...   -0.245922   -1.143721
# ...                                                        ...         ...
# CCOC(=O)Oc1c(OC)cc(cc1OC)C(=O)O[C@@H]1C[C@@H]2C...   -0.245922   -2.469115
# COc1ccc2C[C@@H]3N(C)CCc4cc(OC)c(OC)c(Oc5cc6[C@H...   -0.245922   -2.208142
# CC(C)(C)c1cc(C=C(C#N)C#N)cc(c1O)C(C)(C)C             -0.245922    0.869170
# Cc1cc(cc(C)c1CC1=NCCN1)C(C)(C)C                      -0.245922    1.290882
# CCCOc1ccccc1-c1nc2[nH]nnc2c(=O)[nH]1                 -0.245922    0.719619
#
# [10579 rows x 192 columns]

# %%
model_name = 'rdkit2D'
fname = f'{model_name}_embedding_{dataset_name}.csv'
embedding_dir = '/home/icb/alessandro.palma/data/metadata_processed/original/embeddings/rdkit'

if not os.path.exists(embedding_dir):
    os.mkdir(embedding_dir)

# %%
df = normalized_df.to_csv(os.path.join(embedding_dir, fname))

# %%
np.unique(normalized_df.index)
# Out:
# array(['BrC1=CN2CCS(=O)(=O)N=C2C(Br)=C1', 'Brc1c(Br)c(Br)c2[nH]nnc2c1Br',
#        'Brc1c(CSc2nc3ccccc3s2)nc2ncccn12', ...,
#        'c1nc(cs1)-c1nc2ccccc2[nH]1', 'c1nn(-c2ccccc2)c2ncn3cnnc3c12',
#        'c1nn(nc1-c1nn[nH]n1)-c1ccccc1'], dtype=object)
